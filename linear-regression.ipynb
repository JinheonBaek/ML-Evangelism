# %% [markdown]
# # Linear Regression (Boston dataset)

# %% [markdown]
# ## Import Module

# %%
import numpy as np
import requests
import pandas as pd

# %% [markdown]
# ## Load Dataset

# %%
from sklearn.datasets import load_boston
boston = load_boston()

# %%
# X = features, y = label
X = boston['data']
y = boston['target']

# %%
# Make DataFrame
data = pd.DataFrame(X, columns = boston['feature_names'])
data['target'] = y

# %% [markdown]
# ## Print Dataset

# %%
# data
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %% [markdown]
# ## Gradient Descent

# %% [markdown]
# ### Gradient Descent : one method to fit the linear model

# %%
num_epoch = 100 #???
learning_rate = "Input any value you wants for setting learning rate of your linear-regression model"

# %%
# Parameter 
w = np.random.uniform(low=0.0, high=1.0, size=X.shape[1])
b = np.random.uniform(low=0.0, high=1.0)

# %%
for epoch in range(num_epoch):
    # Predict y (=target)
    y_predict = X.dot(w) + b
    
    # Calculating Error
    error = np.abs(y_predict - y).mean()
    if error < 1:
        break
    
    # Gradient Descent for Multiple Variables
    w = w - learning_rate * ((y_predict - y)).dot(X)
    b = b - learning_rate * (y_predict - y).mean()
    
    # Print Error
    if epoch % 100000 == 0:
        print("{0:6} error = {1:.5f}".format(epoch, error))
# Out:
#      0 error = 314.46105
# 100000 error = 4.24943
# 200000 error = 3.88307
# 300000 error = 3.65039
# 400000 error = 3.50547
# 500000 error = 3.41779
# 600000 error = 3.36465
# 700000 error = 3.33281
# 800000 error = 3.31232
# 900000 error = 3.30175

# %%
print("----" * 10)
print("{0:5} error = {1:.5f}".format(epoch, error))
# Out:
# ----------------------------------------
# 999999 error = 3.29486

# %% [markdown]
# ## Predict

# %%
# Predict using calculated parameter
predict = X.dot(w) + b

# %%
# Make Result DataFrame
result = pd.DataFrame({'actural': y, 'predict': predict})
result['difference'] = np.abs(y - predict)

# %%
# result
result.head()
# Out:
#    actural    predict  difference
# 0     24.0  29.437809    5.437809
# 1     21.6  24.633378    3.033378
# 2     34.7  31.262837    3.437163
# 3     33.4  29.871921    3.528079
# 4     36.2  29.617516    6.582484

# %% [markdown]
# ## Score

# %% [markdown]
# ### Make request to azure function for score

# %%
_url = "https://jinheon-azureml-score.azurewebsites.net/api/Linear-Regression-Score?code=L42/xJsf9/jAJcFFrGuSDsWhqk852BK/zFfUsIug9ZaPaP8w7h70LA=="

# %%
json = {
    "name": "Jinheon",
    "score": result['difference'].mean()
}

# %%
req = requests.request('POST', _url, json = json)

# %%
print(req.json())
# Out:
# Hi Jinheon, Your score is 3.294860172566325
